# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashant43226/Speech-Enhancement-/blob/main/speech_enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import IPython.display as ipd
import librosa
import librosa.display
import scipy
import glob
import numpy as np
import math
import warnings
import pickle
from sklearn.utils import shuffle
import zipfile
# %load_ext tensorboard

# %%
path_to_dataset = "D:\downloads\dataset"

# %%
train_tfrecords_filenames = glob.glob(os.path.join(path_to_dataset, 'train_*'))   ##training data file
val_tfrecords_filenames = glob.glob(os.path.join(path_to_dataset, 'val_*'))       ##validation data file

# suffle the file names for training
np.random.shuffle(train_tfrecords_filenames)
print("Training file names: ", train_tfrecords_filenames)
print("Validation file names: ", val_tfrecords_filenames)
# Out:
# Training file names:  ['D:\\downloads\\dataset\\train_40.tfrecords', 'D:\\downloads\\dataset\\train_6.tfrecords', 'D:\\downloads\\dataset\\train_39.tfrecords', 'D:\\downloads\\dataset\\train_57.tfrecords', 'D:\\downloads\\dataset\\train_54.tfrecords', 'D:\\downloads\\dataset\\train_27.tfrecords', 'D:\\downloads\\dataset\\train_62.tfrecords', 'D:\\downloads\\dataset\\train_34.tfrecords', 'D:\\downloads\\dataset\\train_18.tfrecords', 'D:\\downloads\\dataset\\train_43.tfrecords', 'D:\\downloads\\dataset\\train_48.tfrecords', 'D:\\downloads\\dataset\\train_12.tfrecords', 'D:\\downloads\\dataset\\train_7.tfrecords', 'D:\\downloads\\dataset\\train_25.tfrecords', 'D:\\downloads\\dataset\\train_21.tfrecords', 'D:\\downloads\\dataset\\train_49.tfrecords', 'D:\\downloads\\dataset\\train_60.tfrecords', 'D:\\downloads\\dataset\\train_56.tfrecords', 'D:\\downloads\\dataset\\train_37.tfrecords', 'D:\\downloads\\dataset\\train_5.tfrecords', 'D:\\downloads\\dataset\\train_44.tfrecords', 'D:\\downloads\\dataset\\train_51.tfrecords', 'D:\\downloads\\dataset\\train_14.tfrecords', 'D:\\downloads\\dataset\\train_38.tfrecords', 'D:\\downloads\\dataset\\train_32.tfrecords', 'D:\\downloads\\dataset\\train_31.tfrecords', 'D:\\downloads\\dataset\\train_16.tfrecords', 'D:\\downloads\\dataset\\train_22.tfrecords', 'D:\\downloads\\dataset\\train_42.tfrecords', 'D:\\downloads\\dataset\\train_11.tfrecords', 'D:\\downloads\\dataset\\train_4.tfrecords', 'D:\\downloads\\dataset\\train_15.tfrecords', 'D:\\downloads\\dataset\\train_47.tfrecords', 'D:\\downloads\\dataset\\train_52.tfrecords', 'D:\\downloads\\dataset\\train_17.tfrecords', 'D:\\downloads\\dataset\\train_13.tfrecords', 'D:\\downloads\\dataset\\train_2.tfrecords', 'D:\\downloads\\dataset\\train_23.tfrecords', 'D:\\downloads\\dataset\\train_19.tfrecords', 'D:\\downloads\\dataset\\train_35.tfrecords', 'D:\\downloads\\dataset\\train_20.tfrecords', 'D:\\downloads\\dataset\\train_0.tfrecords', 'D:\\downloads\\dataset\\train_3.tfrecords', 'D:\\downloads\\dataset\\train_55.tfrecords', 'D:\\downloads\\dataset\\train_28.tfrecords', 'D:\\downloads\\dataset\\train_10.tfrecords', 'D:\\downloads\\dataset\\train_59.tfrecords', 'D:\\downloads\\dataset\\train_29.tfrecords', 'D:\\downloads\\dataset\\train_58.tfrecords', 'D:\\downloads\\dataset\\train_24.tfrecords', 'D:\\downloads\\dataset\\train_1.tfrecords', 'D:\\downloads\\dataset\\train_53.tfrecords', 'D:\\downloads\\dataset\\train_61.tfrecords', 'D:\\downloads\\dataset\\train_9.tfrecords', 'D:\\downloads\\dataset\\train_41.tfrecords', 'D:\\downloads\\dataset\\train_33.tfrecords', 'D:\\downloads\\dataset\\train_46.tfrecords', 'D:\\downloads\\dataset\\train_30.tfrecords', 'D:\\downloads\\dataset\\train_8.tfrecords', 'D:\\downloads\\dataset\\train_36.tfrecords', 'D:\\downloads\\dataset\\train_26.tfrecords', 'D:\\downloads\\dataset\\train_45.tfrecords', 'D:\\downloads\\dataset\\train_50.tfrecords']
# Validation file names:  ['D:\\downloads\\dataset\\val_0.tfrecords', 'D:\\downloads\\dataset\\val_1.tfrecords', 'D:\\downloads\\dataset\\val_2.tfrecords']

# %%
windowLength = 256                        # window length is taken as 256 to calculate the 256 point STFT
overlap      = round(0.25 * windowLength) # overlap of 75%
ffTLength    = windowLength               
inputFs      = 48e3                       # input frequency 
fs           = 8e3                        #sampling frequency is taken as 8kHz
numFeatures  = ffTLength//2 + 1
numSegments  = 8
print("windowLength:",windowLength)
print("overlap:",overlap)
print("ffTLength:",ffTLength)
print("inputFs:",inputFs)
print("fs:",fs)
print("numFeatures:",numFeatures)
print("numSegments:",numSegments)
# Out:
# windowLength: 256
# overlap: 64
# ffTLength: 256
# inputFs: 48000.0
# fs: 8000.0
# numFeatures: 129
# numSegments: 8

# %%
mozilla_basepath = 'D:/downloads/fr1/mcv/fr~'                                  ##dataset containing clean audio
urbansound_basepath = 'D:/downloads/UrbanSound8K/UrbanSound8k'                 ##dataset containing noise

# %%
##Short Time Fourier Transform for noise and clean audio

def tf_record_parser(record):
    keys_to_features = {
        "noise_stft_phase": tf.io.FixedLenFeature((), tf.string, default_value=""),
        'noise_stft_mag_features': tf.io.FixedLenFeature([], tf.string),
        "clean_stft_magnitude": tf.io.FixedLenFeature((), tf.string)
    }

    features = tf.io.parse_single_example(record, keys_to_features)

    noise_stft_mag_features = tf.io.decode_raw(features['noise_stft_mag_features'], tf.float32)
    clean_stft_magnitude = tf.io.decode_raw(features['clean_stft_magnitude'], tf.float32)
    noise_stft_phase = tf.io.decode_raw(features['noise_stft_phase'], tf.float32)

    # reshape input and annotation images
    noise_stft_mag_features = tf.reshape(noise_stft_mag_features, (129, 8, 1), name="noise_stft_mag_features")
    clean_stft_magnitude = tf.reshape(clean_stft_magnitude, (129, 1, 1), name="clean_stft_magnitude")
    noise_stft_phase = tf.reshape(noise_stft_phase, (129,), name="noise_stft_phase")

    return noise_stft_mag_features, clean_stft_magnitude

# %%
train_dataset = tf.data.TFRecordDataset([train_tfrecords_filenames])
train_dataset = train_dataset.map(tf_record_parser)
train_dataset = train_dataset.shuffle(8192)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(512)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
test_dataset = tf.data.TFRecordDataset([val_tfrecords_filenames])
test_dataset = test_dataset.map(tf_record_parser)
test_dataset = test_dataset.repeat(1)
test_dataset = test_dataset.batch(512)

# %% [markdown]
#   **TRAIN THE MODEL**

# %%
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, Flatten, Dense, Reshape, Conv2DTranspose, BatchNormalization, Activation 
from tensorflow.keras import Model, backend

# %%
##This model is inspired from U-Net and CR-CED(Cascaded Redundant -Convolutional Encoder Decoder)  
##It consists of 8 Convolutional Layers along with Skip Connections in between with a Leaky ReLU activation function and Batch Normalization
##The model calculates the RMSE loss and uses the Adams Optimizer
 
def build_model(l2_strength):
  
  inputs = Input(shape=[numFeatures,numSegments,1])
  x = inputs

  # -----

  x = tf.keras.layers.ZeroPadding2D(((4,4), (0,0)))(x)
  x = Conv2D(filters=18, kernel_size=[9,8], strides=[1, 1], padding='valid', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  skip0 = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
                 kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(skip0)
  x = BatchNormalization()(x)

  x = Conv2D(filters=32, kernel_size=[9,8], strides=[1,1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

  x = Conv2D(filters=64, kernel_size=[3,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

  # -----
  skip1 = Conv2D(filters=64, kernel_size=[1,1], strides=[1, 1], padding='same', use_bias=False,
                 kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

 #----

  x = Conv2D(filters=32, kernel_size=[3,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

  # ----
  x = Conv2D(filters=32, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

  x = Conv2D(filters=32, kernel_size=[9,8], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.2)(x)

  # ----
  x = tf.keras.layers.SpatialDropout2D(0.2)(x)
  x = Conv2D(filters=1, kernel_size=[129,1], strides=[1, 1], padding='same')(x)

  model = Model(inputs=inputs, outputs=x)

  optimizer = tf.keras.optimizers.Adam(3e-4)
  #optimizer = RAdam(total_steps=10000, warmup_proportion=0.1, min_lr=3e-4)

  model.compile(optimizer=optimizer, loss='mse', 
                metrics=[tf.keras.metrics.RootMeanSquaredError('rmse')])
  return model

# %%
##build the model
model = build_model(l2_strength=0.0)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 129, 8, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 137, 8, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 129, 1, 18)        1296
# _________________________________________________________________
# activation (Activation)      (None, 129, 1, 18)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 129, 1, 18)        72
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 129, 1, 30)        2700
# _________________________________________________________________
# activation_1 (Activation)    (None, 129, 1, 30)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 129, 1, 30)        120
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 129, 1, 32)        69120
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 129, 1, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 129, 1, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 129, 1, 64)        6144
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 129, 1, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 129, 1, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 129, 1, 64)        256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 129, 1, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 129, 1, 32)        6144
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 129, 1, 32)        128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 129, 1, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 129, 1, 32)        5120
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 129, 1, 32)        128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 129, 1, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 129, 1, 32)        73728
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 129, 1, 32)        128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 129, 1, 32)        0
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 129, 1, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 129, 1, 1)         4129
# =================================================================
# Total params: 169,597
# Trainable params: 168,989
# Non-trainable params: 608
# _________________________________________________________________

# %%
# %tensorboard --logdir logs
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 16212.

# %%
tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)

# %%
baseline_val_loss = model.evaluate(test_dataset)[0]
print(f"Baseline accuracy {baseline_val_loss}")
# Out:
# 312/312 [==============================] - 14s 44ms/step - loss: 0.2386 - rmse: 0.4885
# Baseline accuracy 0.23862536251544952

# %%
##Please change the number of epochs and steps per epochs .

early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True, baseline=None)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, update_freq='batch')
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='./denoiser_cnn_log_mel_generator.h5', 
                                                         monitor='val_loss', save_best_only=True)

model.fit(train_dataset,
         steps_per_epoch=50, # you might need to change this
         validation_data=test_dataset,
         epochs=100,          #you might need to change this
         callbacks=[early_stopping_callback, tensorboard_callback, checkpoint_callback]
        )
# Out:
# Epoch 1/100
# 50/50 [==============================] - 25s 478ms/step - loss: 0.2146 - rmse: 0.4632 - val_loss: 0.2371 - val_rmse: 0.4869
# Epoch 2/100
# 50/50 [==============================] - 25s 504ms/step - loss: 0.2119 - rmse: 0.4603 - val_loss: 0.2202 - val_rmse: 0.4693
# Epoch 3/100
# 50/50 [==============================] - 26s 533ms/step - loss: 0.2022 - rmse: 0.4497 - val_loss: 0.1963 - val_rmse: 0.4431
# Epoch 4/100
# 50/50 [==============================] - 28s 575ms/step - loss: 0.2006 - rmse: 0.4479 - val_loss: 0.1993 - val_rmse: 0.4464
# Epoch 5/100
# 50/50 [==============================] - 27s 548ms/step - loss: 0.2060 - rmse: 0.4539 - val_loss: 0.2020 - val_rmse: 0.4494
# Epoch 6/100
# 50/50 [==============================] - 30s 604ms/step - loss: 0.1974 - rmse: 0.4443 - val_loss: 0.1923 - val_rmse: 0.4385
# Epoch 7/100
# 50/50 [==============================] - 26s 535ms/step - loss: 0.1911 - rmse: 0.4371 - val_loss: 0.2151 - val_rmse: 0.4638
# Epoch 8/100
# 50/50 [==============================] - 31s 621ms/step - loss: 0.1903 - rmse: 0.4363 - val_loss: 0.1954 - val_rmse: 0.4421
# Epoch 9/100
# 50/50 [==============================] - 28s 567ms/step - loss: 0.2048 - rmse: 0.4525 - val_loss: 0.2040 - val_rmse: 0.4517
# Epoch 10/100
# 50/50 [==============================] - 30s 599ms/step - loss: 0.2060 - rmse: 0.4539 - val_loss: 0.1907 - val_rmse: 0.4367
# Epoch 11/100
# 50/50 [==============================] - 29s 580ms/step - loss: 0.1944 - rmse: 0.4409 - val_loss: 0.1881 - val_rmse: 0.4337
# Epoch 12/100
# 50/50 [==============================] - 27s 542ms/step - loss: 0.1972 - rmse: 0.4441 - val_loss: 0.1891 - val_rmse: 0.4348
# Epoch 13/100
# 50/50 [==============================] - 27s 539ms/step - loss: 0.1783 - rmse: 0.4222 - val_loss: 0.1872 - val_rmse: 0.4327
# Epoch 14/100
# 50/50 [==============================] - 27s 543ms/step - loss: 0.1785 - rmse: 0.4225 - val_loss: 0.1857 - val_rmse: 0.4309
# Epoch 15/100
# 50/50 [==============================] - 27s 541ms/step - loss: 0.1791 - rmse: 0.4232 - val_loss: 0.1934 - val_rmse: 0.4398
# Epoch 16/100
# 50/50 [==============================] - 27s 547ms/step - loss: 0.1860 - rmse: 0.4313 - val_loss: 0.1823 - val_rmse: 0.4270
# Epoch 17/100
# 50/50 [==============================] - 29s 581ms/step - loss: 0.1879 - rmse: 0.4335 - val_loss: 0.2039 - val_rmse: 0.4515
# Epoch 18/100
# 50/50 [==============================] - 27s 541ms/step - loss: 0.1858 - rmse: 0.4311 - val_loss: 0.1889 - val_rmse: 0.4347
# Epoch 19/100
# 50/50 [==============================] - 26s 534ms/step - loss: 0.1714 - rmse: 0.4140 - val_loss: 0.1848 - val_rmse: 0.4299
# Epoch 20/100
# 50/50 [==============================] - 28s 575ms/step - loss: 0.1732 - rmse: 0.4161 - val_loss: 0.2197 - val_rmse: 0.4687
# Epoch 21/100
# 50/50 [==============================] - 27s 554ms/step - loss: 0.1817 - rmse: 0.4263 - val_loss: 0.1817 - val_rmse: 0.4263
# Epoch 22/100
# 50/50 [==============================] - 28s 574ms/step - loss: 0.1813 - rmse: 0.4258 - val_loss: 0.1967 - val_rmse: 0.4435
# Epoch 23/100
# 50/50 [==============================] - 27s 556ms/step - loss: 0.1751 - rmse: 0.4185 - val_loss: 0.1804 - val_rmse: 0.4247
# Epoch 24/100
# 50/50 [==============================] - 67s 1s/step - loss: 0.1867 - rmse: 0.4321 - val_loss: 0.1868 - val_rmse: 0.4322
# Epoch 25/100
# 50/50 [==============================] - 29s 598ms/step - loss: 0.1825 - rmse: 0.4272 - val_loss: 0.1784 - val_rmse: 0.4223
# Epoch 26/100
# 50/50 [==============================] - 27s 558ms/step - loss: 0.1745 - rmse: 0.4178 - val_loss: 0.1772 - val_rmse: 0.4210
# Epoch 27/100
# 50/50 [==============================] - 29s 580ms/step - loss: 0.1755 - rmse: 0.4190 - val_loss: 0.1856 - val_rmse: 0.4309
# Epoch 28/100
# 50/50 [==============================] - 27s 539ms/step - loss: 0.1703 - rmse: 0.4127 - val_loss: 0.1812 - val_rmse: 0.4257
# Epoch 29/100
# 50/50 [==============================] - 27s 538ms/step - loss: 0.1759 - rmse: 0.4194 - val_loss: 0.1770 - val_rmse: 0.4207
# Epoch 30/100
# 50/50 [==============================] - 26s 532ms/step - loss: 0.1683 - rmse: 0.4102 - val_loss: 0.1754 - val_rmse: 0.4188
# Epoch 31/100
# 50/50 [==============================] - 23s 465ms/step - loss: 0.1707 - rmse: 0.4132 - val_loss: 0.1945 - val_rmse: 0.4410
# Epoch 32/100
# 50/50 [==============================] - 23s 475ms/step - loss: 0.1778 - rmse: 0.4217 - val_loss: 0.1867 - val_rmse: 0.4321
# Epoch 33/100
# 50/50 [==============================] - 62s 1s/step - loss: 0.1799 - rmse: 0.4242 - val_loss: 0.1835 - val_rmse: 0.4284
# Epoch 34/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.1652 - rmse: 0.4064 - val_loss: 0.1983 - val_rmse: 0.4453
# Epoch 35/100
# 50/50 [==============================] - 26s 528ms/step - loss: 0.1874 - rmse: 0.4329 - val_loss: 0.1883 - val_rmse: 0.4339
# Epoch 36/100
# 50/50 [==============================] - 33s 669ms/step - loss: 0.1783 - rmse: 0.4223 - val_loss: 0.1869 - val_rmse: 0.4323
# Epoch 37/100
# 50/50 [==============================] - 29s 583ms/step - loss: 0.1792 - rmse: 0.4234 - val_loss: 0.1718 - val_rmse: 0.4145
# Epoch 38/100
# 50/50 [==============================] - 37s 758ms/step - loss: 0.1733 - rmse: 0.4163 - val_loss: 0.1761 - val_rmse: 0.4196
# Epoch 39/100
# 50/50 [==============================] - 23s 474ms/step - loss: 0.1650 - rmse: 0.4062 - val_loss: 0.1745 - val_rmse: 0.4177
# Epoch 40/100
# 50/50 [==============================] - 23s 463ms/step - loss: 0.1651 - rmse: 0.4063 - val_loss: 0.1795 - val_rmse: 0.4237
# Epoch 41/100
# 50/50 [==============================] - 23s 469ms/step - loss: 0.1735 - rmse: 0.4165 - val_loss: 0.1899 - val_rmse: 0.4357
# Epoch 42/100
# 50/50 [==============================] - 23s 464ms/step - loss: 0.1807 - rmse: 0.4250 - val_loss: 0.1845 - val_rmse: 0.4295
# Epoch 43/100
# 50/50 [==============================] - 61s 1s/step - loss: 0.1654 - rmse: 0.4067 - val_loss: 0.1808 - val_rmse: 0.4252
# Epoch 44/100
# 50/50 [==============================] - 38s 776ms/step - loss: 0.1722 - rmse: 0.4150 - val_loss: 0.1717 - val_rmse: 0.4143
# Epoch 45/100
# 50/50 [==============================] - 23s 463ms/step - loss: 0.1730 - rmse: 0.4160 - val_loss: 0.1782 - val_rmse: 0.4222
# Epoch 46/100
# 50/50 [==============================] - 23s 470ms/step - loss: 0.1929 - rmse: 0.4392 - val_loss: 0.1804 - val_rmse: 0.4247
# Epoch 47/100
# 50/50 [==============================] - 23s 463ms/step - loss: 0.1774 - rmse: 0.4212 - val_loss: 0.1729 - val_rmse: 0.4158
# Epoch 48/100
# 50/50 [==============================] - 23s 468ms/step - loss: 0.1794 - rmse: 0.4235 - val_loss: 0.1933 - val_rmse: 0.4396
# Epoch 49/100
# 50/50 [==============================] - 23s 468ms/step - loss: 0.1772 - rmse: 0.4210 - val_loss: 0.1801 - val_rmse: 0.4243
# Epoch 50/100
# 50/50 [==============================] - 25s 512ms/step - loss: 0.1626 - rmse: 0.4032 - val_loss: 0.1781 - val_rmse: 0.4220
# Epoch 51/100
# 50/50 [==============================] - 26s 526ms/step - loss: 0.1825 - rmse: 0.4271 - val_loss: 0.1821 - val_rmse: 0.4268
# Epoch 52/100
# 50/50 [==============================] - 63s 1s/step - loss: 0.1615 - rmse: 0.4018 - val_loss: 0.1730 - val_rmse: 0.4160
# Epoch 53/100
# 50/50 [==============================] - 44s 885ms/step - loss: 0.1642 - rmse: 0.4052 - val_loss: 0.1882 - val_rmse: 0.4338
# Epoch 54/100
# 50/50 [==============================] - 25s 513ms/step - loss: 0.1802 - rmse: 0.4245 - val_loss: 0.1784 - val_rmse: 0.4224
# Epoch 55/100
# 50/50 [==============================] - 25s 514ms/step - loss: 0.1732 - rmse: 0.4162 - val_loss: 0.1785 - val_rmse: 0.4224
# Epoch 56/100
# 50/50 [==============================] - 23s 464ms/step - loss: 0.1611 - rmse: 0.4014 - val_loss: 0.1838 - val_rmse: 0.4287
# Epoch 57/100
# 50/50 [==============================] - 23s 463ms/step - loss: 0.1619 - rmse: 0.4023 - val_loss: 0.1712 - val_rmse: 0.4138
# Epoch 58/100
# 50/50 [==============================] - 23s 472ms/step - loss: 0.1779 - rmse: 0.4218 - val_loss: 0.2056 - val_rmse: 0.4534
# Epoch 59/100
# 50/50 [==============================] - 23s 465ms/step - loss: 0.1544 - rmse: 0.3930 - val_loss: 0.1787 - val_rmse: 0.4227
# Epoch 60/100
# 50/50 [==============================] - 24s 493ms/step - loss: 0.1621 - rmse: 0.4027 - val_loss: 0.1744 - val_rmse: 0.4176
# Epoch 61/100
# 50/50 [==============================] - 62s 1s/step - loss: 0.1736 - rmse: 0.4166 - val_loss: 0.1788 - val_rmse: 0.4228
# Epoch 62/100
# 50/50 [==============================] - 47s 946ms/step - loss: 0.1712 - rmse: 0.4137 - val_loss: 0.1770 - val_rmse: 0.4207
# Epoch 63/100
# 50/50 [==============================] - 23s 475ms/step - loss: 0.1656 - rmse: 0.4070 - val_loss: 0.1800 - val_rmse: 0.4243
# Epoch 64/100
# 50/50 [==============================] - 24s 479ms/step - loss: 0.1704 - rmse: 0.4128 - val_loss: 0.1736 - val_rmse: 0.4166
# Epoch 65/100
# 50/50 [==============================] - 23s 469ms/step - loss: 0.1590 - rmse: 0.3987 - val_loss: 0.1710 - val_rmse: 0.4135
# Epoch 66/100
# 50/50 [==============================] - 23s 472ms/step - loss: 0.1704 - rmse: 0.4128 - val_loss: 0.1742 - val_rmse: 0.4174
# Epoch 67/100
# 50/50 [==============================] - 25s 513ms/step - loss: 0.1590 - rmse: 0.3987 - val_loss: 0.1704 - val_rmse: 0.4128
# Epoch 68/100
# 50/50 [==============================] - 23s 474ms/step - loss: 0.1741 - rmse: 0.4172 - val_loss: 0.1782 - val_rmse: 0.4221
# Epoch 69/100
# 50/50 [==============================] - 24s 482ms/step - loss: 0.1706 - rmse: 0.4130 - val_loss: 0.1847 - val_rmse: 0.4298
# Epoch 70/100
# 50/50 [==============================] - 61s 1s/step - loss: 0.1569 - rmse: 0.3961 - val_loss: 0.1686 - val_rmse: 0.4107
# Epoch 71/100
# 50/50 [==============================] - 46s 938ms/step - loss: 0.1651 - rmse: 0.4063 - val_loss: 0.1710 - val_rmse: 0.4135
# Epoch 72/100
# 50/50 [==============================] - 26s 519ms/step - loss: 0.1745 - rmse: 0.4178 - val_loss: 0.1699 - val_rmse: 0.4122
# Epoch 73/100
# 50/50 [==============================] - 23s 475ms/step - loss: 0.1636 - rmse: 0.4045 - val_loss: 0.1765 - val_rmse: 0.4202
# Epoch 74/100
# 50/50 [==============================] - 26s 519ms/step - loss: 0.1686 - rmse: 0.4106 - val_loss: 0.1703 - val_rmse: 0.4127
# Epoch 75/100
# 50/50 [==============================] - 23s 476ms/step - loss: 0.1707 - rmse: 0.4132 - val_loss: 0.1853 - val_rmse: 0.4305
# Epoch 76/100
# 50/50 [==============================] - 23s 470ms/step - loss: 0.1645 - rmse: 0.4056 - val_loss: 0.1694 - val_rmse: 0.4115
# Epoch 77/100
# 50/50 [==============================] - 23s 469ms/step - loss: 0.1653 - rmse: 0.4065 - val_loss: 0.1689 - val_rmse: 0.4110
# Epoch 78/100
# 50/50 [==============================] - 30s 602ms/step - loss: 0.1604 - rmse: 0.4005 - val_loss: 0.1831 - val_rmse: 0.4279
# Epoch 79/100
# 50/50 [==============================] - 62s 1s/step - loss: 0.1571 - rmse: 0.3963 - val_loss: 0.1658 - val_rmse: 0.4071
# Epoch 80/100
# 50/50 [==============================] - 39s 796ms/step - loss: 0.1791 - rmse: 0.4232 - val_loss: 0.1667 - val_rmse: 0.4083
# Epoch 81/100
# 50/50 [==============================] - 26s 524ms/step - loss: 0.1671 - rmse: 0.4087 - val_loss: 0.1672 - val_rmse: 0.4090
# Epoch 82/100
# 50/50 [==============================] - 23s 469ms/step - loss: 0.1653 - rmse: 0.4066 - val_loss: 0.1751 - val_rmse: 0.4184
# Epoch 83/100
# 50/50 [==============================] - 28s 573ms/step - loss: 0.1659 - rmse: 0.4073 - val_loss: 0.1679 - val_rmse: 0.4098
# Epoch 84/100
# 50/50 [==============================] - 26s 523ms/step - loss: 0.1654 - rmse: 0.4067 - val_loss: 0.1674 - val_rmse: 0.4092
# Epoch 85/100
# 50/50 [==============================] - 26s 522ms/step - loss: 0.1711 - rmse: 0.4137 - val_loss: 0.1634 - val_rmse: 0.4043
# Epoch 86/100
# 50/50 [==============================] - 25s 510ms/step - loss: 0.1649 - rmse: 0.4061 - val_loss: 0.1747 - val_rmse: 0.4180
# Epoch 87/100
# 50/50 [==============================] - 25s 505ms/step - loss: 0.1601 - rmse: 0.4001 - val_loss: 0.1742 - val_rmse: 0.4173
# Epoch 88/100
# 50/50 [==============================] - 25s 512ms/step - loss: 0.1594 - rmse: 0.3993 - val_loss: 0.1699 - val_rmse: 0.4121
# Epoch 89/100
# 50/50 [==============================] - 63s 1s/step - loss: 0.1600 - rmse: 0.4000 - val_loss: 0.1736 - val_rmse: 0.4166
# Epoch 90/100
# 50/50 [==============================] - 63s 1s/step - loss: 0.1655 - rmse: 0.4069 - val_loss: 0.1731 - val_rmse: 0.4160
# Epoch 91/100
# 50/50 [==============================] - 25s 513ms/step - loss: 0.1698 - rmse: 0.4120 - val_loss: 0.1819 - val_rmse: 0.4264
# Epoch 92/100
# 50/50 [==============================] - 26s 528ms/step - loss: 0.1909 - rmse: 0.4369 - val_loss: 0.1665 - val_rmse: 0.4080
# Epoch 93/100
# 50/50 [==============================] - 26s 528ms/step - loss: 0.1692 - rmse: 0.4113 - val_loss: 0.1798 - val_rmse: 0.4240
# Epoch 94/100
# 50/50 [==============================] - 26s 524ms/step - loss: 0.1605 - rmse: 0.4006 - val_loss: 0.1724 - val_rmse: 0.4152
# Epoch 95/100
# 50/50 [==============================] - 26s 530ms/step - loss: 0.1715 - rmse: 0.4141 - val_loss: 0.1693 - val_rmse: 0.4115
# Epoch 96/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1539 - rmse: 0.3923 - val_loss: 0.1661 - val_rmse: 0.4076
# Epoch 97/100
# 50/50 [==============================] - 64s 1s/step - loss: 0.1700 - rmse: 0.4123 - val_loss: 0.1713 - val_rmse: 0.4139
# Epoch 98/100
# 50/50 [==============================] - 24s 495ms/step - loss: 0.1633 - rmse: 0.4042 - val_loss: 0.1698 - val_rmse: 0.4121
# Epoch 99/100
# 50/50 [==============================] - 23s 471ms/step - loss: 0.1496 - rmse: 0.3868 - val_loss: 0.1661 - val_rmse: 0.4075
# Epoch 100/100
# 50/50 [==============================] - 24s 488ms/step - loss: 0.1741 - rmse: 0.4172 - val_loss: 0.1689 - val_rmse: 0.4110

# %%
val_loss = model.evaluate(test_dataset)[0]
if val_loss < baseline_val_loss:
  print("New model saved.")
  model.save('./denoiser_cnn_log_mel_generator.h5')
# Out:
# 312/312 [==============================] - 14s 46ms/step - loss: 0.1689 - rmse: 0.4110
# New model saved.

# %% [markdown]
# **TEST THE MODEL**

# %%
def read_audio(filepath, sample_rate, normalize=True):
    """Read an audio file and return it as a numpy array"""
    audio, sr = librosa.load(filepath, sr=sample_rate)
    if normalize:
      div_fac = 1 / np.max(np.abs(audio)) / 3.0
      audio = audio * div_fac
    return audio, sr
        
def add_noise_to_clean_audio(clean_audio, noise_signal):
    """Adds noise to an audio sample"""
    if len(clean_audio) >= len(noise_signal):
        # print("The noisy signal is smaller than the clean audio input. Duplicating the noise.")
        while len(clean_audio) >= len(noise_signal):
            noise_signal = np.append(noise_signal, noise_signal)

    ## Extract a noise segment from a random location in the noise file
    ind = np.random.randint(0, noise_signal.size - clean_audio.size)

    noiseSegment = noise_signal[ind: ind + clean_audio.size]

    speech_power = np.sum(clean_audio ** 2)
    noise_power = np.sum(noiseSegment ** 2)
    noisyAudio = clean_audio + np.sqrt(speech_power / noise_power) * noiseSegment
    return noisyAudio

def play(audio, sample_rate):
    ipd.display(ipd.Audio(data=audio, rate=sample_rate))

# %%
##Use librosa to get Short Time Fourier Transform spectrogram 
class FeatureExtractor:
    def __init__(self, audio, *, windowLength, overlap, sample_rate):
        self.audio = audio
        self.ffT_length = windowLength
        self.window_length = windowLength
        self.overlap = overlap
        self.sample_rate = sample_rate
        self.window = scipy.signal.hamming(self.window_length, sym=False)

    def get_stft_spectrogram(self):
        return librosa.stft(self.audio, n_fft=self.ffT_length, win_length=self.window_length, hop_length=self.overlap,
                            window=self.window, center=True)

    def get_audio_from_stft_spectrogram(self, stft_features):
        return librosa.istft(stft_features, win_length=self.window_length, hop_length=self.overlap,
                             window=self.window, center=True)

    def get_mel_spectrogram(self):
        return librosa.feature.melspectrogram(self.audio, sr=self.sample_rate, power=2.0, pad_mode='reflect',
                                           n_fft=self.ffT_length, hop_length=self.overlap, center=True)

    def get_audio_from_mel_spectrogram(self, M):
        return librosa.feature.inverse.mel_to_audio(M, sr=self.sample_rate, n_fft=self.ffT_length, hop_length=self.overlap,
                                             win_length=self.window_length, window=self.window,
                                             center=True, pad_mode='reflect', power=2.0, n_iter=32, length=None)

# %%
##Listen to the clean audio ##os.path.join(mozilla_basepath, 'test', 'common_voice_en_16526.mp3')
cleanAudio, sr = read_audio(os.path.join(mozilla_basepath+'/clips/'+'00a0e09969d82b9cc65e6a03a95e298b4d4479e89c9fe6a2ed926324633fdb0293e593ce569c65f5f190848bec56591675b4c8f8b9dfdacddebc61e5593d52ee'+'.mp3'), sample_rate=fs)
print("Min:", np.min(cleanAudio),"Max:",np.max(cleanAudio))
ipd.Audio(data=cleanAudio, rate=sr)
# Out:
# C:\Users\prash\Anaconda3\envs\tf_gpu\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Min: -0.26955077 Max: 0.33333334
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
##Listen to the noise D:\downloads\UrbanSound8K\UrbanSound8K\audio\fold7\66619-2-0-22.wav
noiseAudio, sr = read_audio(os.path.join(urbansound_basepath+'/audio'+'/fold3/'+'17615-3-0-0'+'.wav'), sample_rate=fs)
print("Min:", np.min(noiseAudio),"Max:",np.max(noiseAudio))
ipd.Audio(data=noiseAudio, rate=sr)
# Out:
# Min: -0.29915252 Max: 0.33333334
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cleanAudioFeatureExtractor = FeatureExtractor(cleanAudio, windowLength=windowLength, overlap=overlap, sample_rate=sr)
stft_features = cleanAudioFeatureExtractor.get_stft_spectrogram()
stft_features = np.abs(stft_features)
print("Min:", np.min(stft_features),"Max:",np.max(stft_features))
# Out:
# Min: 1.4618468e-10 Max: 6.007656

# %%
##Listen to the clean audio+noise
noisyAudio = add_noise_to_clean_audio(cleanAudio, noiseAudio)
ipd.Audio(data=noisyAudio, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def prepare_input_features(stft_features):
    # Phase Aware Scaling: To avoid extreme differences (more than
    # 45 degree) between the noisy and clean phase, the clean spectral magnitude was encoded as similar to [21]:
    noisySTFT = np.concatenate([stft_features[:,0:numSegments-1], stft_features], axis=1)
    stftSegments = np.zeros((numFeatures, numSegments , noisySTFT.shape[1] - numSegments + 1))

    for index in range(noisySTFT.shape[1] - numSegments + 1):
        stftSegments[:,:,index] = noisySTFT[:,index:index + numSegments]
    return stftSegments

# %%
noiseAudioFeatureExtractor = FeatureExtractor(noisyAudio, windowLength=windowLength, overlap=overlap, sample_rate=sr)
noise_stft_features = noiseAudioFeatureExtractor.get_stft_spectrogram()

# At reconstruction, noisy spectral phase was used instead to
# perform in- verse STFT and recover human speech.

noisyPhase = np.angle(noise_stft_features)
print(noisyPhase.shape)
noise_stft_features = np.abs(noise_stft_features)

mean = np.mean(noise_stft_features)
std = np.std(noise_stft_features)
noise_stft_features = (noise_stft_features - mean) / std
# Out:
# (129, 424)

# %%
predictors = prepare_input_features(noise_stft_features)

# %%
predictors = np.reshape(predictors, (predictors.shape[0], predictors.shape[1], 1, predictors.shape[2]))
predictors = np.transpose(predictors, (3, 0, 1, 2)).astype(np.float32)
print('predictors.shape:', predictors.shape)
# Out:
# predictors.shape: (424, 129, 8, 1)

# %%
STFTmodel = model.predict(predictors)
print(STFTmodel.shape)
# Out:
# (424, 129, 1, 1)

# %%
def revert_features_to_audio(features, phase, cleanMean=None, cleanStd=None):
    # scale the outpus back to the original range
    if cleanMean and cleanStd:
        features = cleanStd * features + cleanMean

    phase = np.transpose(phase, (1, 0))
    features = np.squeeze(features)

    # features = librosa.db_to_power(features)
    features = features * np.exp(1j * phase)  # that fixes the abs() ope previously done

    features = np.transpose(features, (1, 0))
    return noiseAudioFeatureExtractor.get_audio_from_stft_spectrogram(features)

# %%
##Final denoised audio 
denoisedAudio = revert_features_to_audio(STFTmodel, noisyPhase, mean, std)
print("Min:", np.min(denoisedAudio),"Max:",np.max(denoisedAudio))
ipd.Audio(data=denoisedAudio, rate=fs)
# Out:
# Min: -0.19005851 Max: 0.2935531
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,1,1)
plt.plot(cleanAudio)
plt.title("Clean Audio")

plt.subplot(3,1,2)
plt.plot(noisyAudio)
plt.title("Noisy Audio")

plt.subplot(3,1,3)
plt.plot(denoisedAudio)
plt.title("Denoised Audio")
# Out:
# Text(0.5, 1.0, 'Denoised Audio')

# %%
##Function to get spectrogram
def get_spectrogram(waveform):
  # Padding for files with less than 16000 samples
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)

  return spectrogram

# %%
spectrogram_clean = get_spectrogram(cleanAudio)
spectrogram_noise=get_spectrogram(noiseAudio)
spectrogram_denoised_audio=get_spectrogram(denoisedAudio)

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,1,1)
plt.plot(spectrogram_clean)
plt.title("Clean Audio")

plt.subplot(3,1,2)
plt.plot(spectrogram_noise)
plt.title("Noisy Audio")

plt.subplot(3,1,3)
plt.plot(spectrogram_denoised_audio)
plt.title("Denoised Audio")
# Out:
# C:\Users\prash\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\prash\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\prash\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Denoised Audio')
